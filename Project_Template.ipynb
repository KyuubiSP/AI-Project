# %% [markdown]
# # Recommendation System Project Template
#
# ## Instructions
#
# Use this notebook as the **official project report + code submission**.

# %% [markdown]
# ### Rules
# - Write explanations in **Markdown cells** and implementation in **Code cells**.
# - The notebook must run **top to bottom**.
# - Every claim about performance must be supported by results shown in the notebook.
# - Clearly report any use of AI tools.

# %% [markdown]
# ### Evaluation alignment
# This notebook is structured to support evaluation on:
# 1. Problem definition and motivation
# 2. Baseline design
# 3. Model implementation
# 4. Evaluation methodology
# 5. Experimental results
# 6. Discussion and interpretation
# 7. Reproducibility

# %% [markdown]
# # Metadata
#
# Please complete all fields below.
#
# ```yaml
# project_title: ""
# dataset_name: ""
# task_type: "recommender_system"
# methods:
#   - memory_based_user_cf
#   - neural_collaborative_filtering
# evaluation_metrics:
#   - RMSE
#   - MAE
#   - Precision@K
#   - Recall@K
# team_members:
#   - name:
#     student_id:
#     role:
#   - name:
#     student_id:
#     role:
#
#
# Submission date:
#
# ```

# %% [markdown]
# # Contribution Tracking Rules
#
# Each section MUST begin with:
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```

# %% [markdown]
# ## AI Usage Declaration
#
# Fill in the following table.
#
# | Item | Response |
# |---|---|
# | Did you use generative AI tools? | Yes / No |
# | Which tools? |  |
# | For what purpose? | brainstorming / coding help / debugging / writing / other |
# | Which parts were AI-assisted? |  |
# | What did you verify yourself? |  |
#
# ### Short declaration
# Write 4–6 lines describing how you used AI and how you ensured the correctness of your work.

# %% [markdown]
# ## 1. Problem Definition and Motivation
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Here you should describe the recommendation task clearly.
#
# For example:
# - What is being recommended?
# - Who are the users?
# - What are the items?
# - What is the prediction target?
# - Is this a **rating prediction**, **top-N recommendation**, or **ranking** task?
# - Why is the problem relevant?
#
# ### Expected output
# A short but precise project statement that makes the task unambiguous.

# %% [markdown]
# ## 2. Dataset Description
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Describe the dataset used.
#
# Include:
# - Dataset name and source
# - Number of users
# - Number of items
# - Number of interactions
# - Available features
# - Missing data issues
#
# If you use a subset, explain how and why.

# %% [markdown]
# ## 3. Data Exploration and Preprocessing
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Explain:
# - preprocessing steps
# - filtering decisions
# - cleaning operations
# - feature engineering

# %% [markdown]
# ## 4. Baseline Recommender
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# It is reccomandable to Implement and explain at least one **baseline**.
#
# Examples: check the slides !
# - user-based collaborative filtering
# - item-based collaborative filtering
# - content-based recommendation
#
# ### Why this matters
# A project is much easier to evaluate fairly when the proposed method is compared to a simple baseline.

# %% [markdown]
# ## 5. Proposed Recommendation Model
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Describe the model you propose.
#
# Include:
# - intuition
# - important design choices
# - hyperparameters
# - training procedure
# - why this model is appropriate for the task
#
# Example:
# - deep-based recommender

# %% [markdown]
# ## 6. Evaluation Methodology
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Explain how you evaluate the recommender.
#
# Include:
# - which metrics you use
# - why those metrics are appropriate
# - what constitutes a relevant item
# - how you compare with baselines
#
# Typical metrics:
# - Precision@K
# - Recall@K
# - MAP@K
# - RMSE / MAE (rating prediction)

# %% [markdown]
# ## 7. Experimental Results
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Report the experimental design and your results clearly.
#
# Include:
# - baseline results
# - model results
# - tables or plots
# - comparison across metrics
# - concise summary of the main outcome
#
# ### Important
# Do not only show final numbers. Make the comparison explicit.

# %% [markdown]
# ## 8. Discussion and Interpretation
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Interpret your results.
#
# Discuss: This section should be about **reasoning**, not just repeating numbers.

# %% [markdown]
# ## 9. Limitations, Fairness,
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Discuss relevant issues such as:
# - cold-start problem
#
# Be specific to your project.

# %% [markdown]
# ## 10. Reproducibility
#
#
# ```markdown
# ## Contribution Metadata
# Author(s):
# Section:
# Method: [keyterms]
# SHORT Description of contribution:
#
# Difficulty: BASIC / INTERMEDIATE / ADVANCED
# ```
# ### What to write
# Provide exact instructions to reproduce the results.
#
# Include:
# - package versions
# - execution order
# - external files needed
# - runtime considerations
#
# A good project should be reproducible by the instructor with minimal effort.

# %% [markdown]
# ## 11. Final Conclusion
#
# Summarize using max 10 lines:
# - the problem
# - the approach
# - the main result
# - the main limitation
# - the most important future improvement

# %% [markdown]
# ## 12. Self-Evaluation (Optional but Recommended)
#
# Use the rubric below to self-assess your work before submission.
#
# | Criterion | Self-score (0–4) | Short justification |
# |---|---:|---|
# | Problem definition and motivation |  |  |
# | Data handling |  |  |
# | Baseline design |  |  |
# | Model implementation |  |  |
# | Evaluation methodology |  |  |
# | Experimental results |  |  |
# | Discussion and interpretation |  |  |
# | Limitations  |  |  |
# | Reproducibility  |  |  |

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, verify that:
# - [ ] all required sections are filled
# - [ ] the notebook runs from top to bottom
# - [ ] figures and tables are visible
# - [ ] baseline and proposed model are both evaluated
# - [ ] claims are supported by evidence
# - [ ] AI usage is declared
# - [ ] file paths are correct
# - [ ] the notebook is clean and readable
